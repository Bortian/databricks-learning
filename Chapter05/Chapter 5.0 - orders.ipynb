# %%
# Import the required modules
import random
import json
from kafka import KafkaProducer
import time

# using datetime module
import datetime;

# Define the bootstrap servers and the topic name
bootstrap_servers = "kafka:9092"
topic = "orders"

# Create a Kafka producer with JSON value serializer
producer = KafkaProducer(bootstrap_servers=bootstrap_servers)

# Define the product IDs and the quantities
product_ids = [1001, 1002, 1003, 1004, 1005]
quantities = [1, 2, 3, 4, 5]

# Define a function to generate random event data
def generate_orders():
    current_time = time.time()
    order_id = random.randint(100000, 999999)
    product_id = random.choice(product_ids)
    quantity = random.choice(quantities)
    timestamp = datetime.datetime.fromtimestamp(current_time).strftime("%m/%d/%Y, %H:%M:%S")
    
    # Create an order dictionary
    return {"order_id": order_id, "product_id": product_id, "quantity": quantity,"timestamp": timestamp}
# Loop to generate and send events
while True:
  # Generate a random event
  order = generate_orders()
  # Print the event to the console
  print(order)
  # Send the event to the Kafka topic
    
  producer.send(topic, value=json.dumps(order).encode('utf-8'))
  time.sleep(10)
# Out:
# {'order_id': 252907, 'product_id': 1003, 'quantity': 1, 'timestamp': '06/11/2025, 08:54:00'}
# {'order_id': 360689, 'product_id': 1004, 'quantity': 3, 'timestamp': '06/11/2025, 08:54:11'}
# {'order_id': 205462, 'product_id': 1004, 'quantity': 4, 'timestamp': '06/11/2025, 08:54:21'}
# {'order_id': 836035, 'product_id': 1003, 'quantity': 3, 'timestamp': '06/11/2025, 08:54:31'}
# {'order_id': 181267, 'product_id': 1004, 'quantity': 3, 'timestamp': '06/11/2025, 08:54:41'}
# {'order_id': 426259, 'product_id': 1001, 'quantity': 5, 'timestamp': '06/11/2025, 08:54:51'}
# {'order_id': 927266, 'product_id': 1002, 'quantity': 4, 'timestamp': '06/11/2025, 08:55:01'}
# {'order_id': 528685, 'product_id': 1004, 'quantity': 5, 'timestamp': '06/11/2025, 08:55:11'}
# {'order_id': 498144, 'product_id': 1003, 'quantity': 4, 'timestamp': '06/11/2025, 08:55:21'}
# {'order_id': 266822, 'product_id': 1005, 'quantity': 4, 'timestamp': '06/11/2025, 08:55:31'}
# {'order_id': 754658, 'product_id': 1002, 'quantity': 3, 'timestamp': '06/11/2025, 08:55:41'}
# {'order_id': 926743, 'product_id': 1004, 'quantity': 3, 'timestamp': '06/11/2025, 08:55:51'}
# {'order_id': 519920, 'product_id': 1004, 'quantity': 5, 'timestamp': '06/11/2025, 08:56:01'}
# {'order_id': 492369, 'product_id': 1002, 'quantity': 2, 'timestamp': '06/11/2025, 08:56:11'}
# {'order_id': 414543, 'product_id': 1002, 'quantity': 2, 'timestamp': '06/11/2025, 08:56:21'}
# {'order_id': 307310, 'product_id': 1005, 'quantity': 3, 'timestamp': '06/11/2025, 08:56:31'}
# {'order_id': 326957, 'product_id': 1005, 'quantity': 3, 'timestamp': '06/11/2025, 08:56:41'}
# {'order_id': 989293, 'product_id': 1004, 'quantity': 1, 'timestamp': '06/11/2025, 08:56:51'}
# {'order_id': 186466, 'product_id': 1002, 'quantity': 5, 'timestamp': '06/11/2025, 08:57:01'}
# {'order_id': 139492, 'product_id': 1002, 'quantity': 3, 'timestamp': '06/11/2025, 08:57:11'}
# {'order_id': 815444, 'product_id': 1004, 'quantity': 1, 'timestamp': '06/11/2025, 08:57:21'}
# {'order_id': 100199, 'product_id': 1005, 'quantity': 2, 'timestamp': '06/11/2025, 08:57:31'}
# {'order_id': 899105, 'product_id': 1004, 'quantity': 4, 'timestamp': '06/11/2025, 08:57:41'}
# {'order_id': 780893, 'product_id': 1003, 'quantity': 1, 'timestamp': '06/11/2025, 08:57:51'}
# {'order_id': 465130, 'product_id': 1002, 'quantity': 2, 'timestamp': '06/11/2025, 08:58:01'}
# {'order_id': 825175, 'product_id': 1005, 'quantity': 3, 'timestamp': '06/11/2025, 08:58:11'}
# {'order_id': 716091, 'product_id': 1004, 'quantity': 5, 'timestamp': '06/11/2025, 08:58:21'}
# {'order_id': 757988, 'product_id': 1002, 'quantity': 4, 'timestamp': '06/11/2025, 08:58:31'}
# {'order_id': 624051, 'product_id': 1002, 'quantity': 5, 'timestamp': '06/11/2025, 08:58:41'}
# {'order_id': 528653, 'product_id': 1003, 'quantity': 3, 'timestamp': '06/11/2025, 08:58:51'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 40
#      37 # Send the event to the Kafka topic
#      39 producer.send(topic, value=json.dumps(order).encode('utf-8'))
# ---> 40 time.sleep(10)
#
# KeyboardInterrupt:
